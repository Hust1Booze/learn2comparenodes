# %%
import os
import sys
import networkx as nx
import random
import pyscipopt as sp
import numpy as np
import multiprocessing as md
from functools import partial
import imp

import gisp
import fcmcnf

# %load_ext autoreload 
# %autoreload 2



def distribute(n_instance, n_cpu):
    if n_cpu == 1:
        return [(0, n_instance)]
    
    k = n_instance //( n_cpu -1 )
    r = n_instance % (n_cpu - 1 )
    res = []
    for i in range(n_cpu -1):
        res.append( ((k*i), (k*(i+1))) )
    
    res.append(((n_cpu - 1) *k ,(n_cpu - 1) *k + r ))
    return res
# Out:
# /tmp/ipykernel_61462/1375317399.py:9: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp

# %%
n_cpu = 16
n_instance = 1000 

problem = 'FCMCNF'

data_partition = 'train' #'valid'


instance = None
solveInstance = True
exp_dir = f"data/{problem}/{data_partition}"


er_prob = 0.3
whichSet = 'SET2'
setParam = 100.0
alphaE2 = 0.5
timelimit = 7200.0

seed = 591

min_n = 15
max_n = 15

min_n_commodities = int(1.5*max_n)
max_n_commodities = int(1.5*max_n)

assert exp_dir is not None
if instance is None:
    assert min_n is not None
    assert max_n is not None

exp_dir = exp_dir 
lp_dir= os.path.join(os.path.abspath('.'), exp_dir)
try:
    os.makedirs(lp_dir)
except FileExistsError:
    ""

print(f"Summary for {problem} generation")
print(f"n_instance    :     {n_instance}")
print(f"size interval :     {min_n, max_n}")
print(f"n_cpu         :     {n_cpu} ")
print(f"solve         :     {solveInstance}")
print(f"saving dir    :     {lp_dir}")



cpu_count = md.cpu_count()//2 if n_cpu == None else n_cpu
# Out:
# Summary for FCMCNF generation
# n_instance    :     1000
# size interval :     (15, 15)
# n_cpu         :     16
# solve         :     True
# saving dir    :     /data/ltf/code/learn2comparenodes/problem_generation/data/FCMCNF/train

# %%
if problem == 'GISP':
    processes = [  md.Process(name=f"worker {p}", target=partial(gisp.generate_instances,
                                                                  seed + p1, 
                                                                  seed + p2, 
                                                                  whichSet, 
                                                                  setParam, 
                                                                  alphaE2, 
                                                                  min_n, 
                                                                  max_n, 
                                                                  er_prob, 
                                                                  instance, 
                                                                  lp_dir, 
                                                                  solveInstance))


                 for p,(p1,p2) in enumerate(distribute(n_instance, n_cpu)) ]

elif problem == 'FCMCNF':

#=============================================================================
    processes = [  md.Process(name=f"worker {p}", target=partial(fcmcnf.generate_instances,
                                                                  seed + p1, 
                                                                  seed + p2, 
                                                                  min_n,
                                                                  max_n,
                                                                  min_n_commodities,
                                                                  max_n_commodities,
                                                                  er_prob,
                                                                  lp_dir, 
                                                                  solveInstance))


                  for p,(p1,p2) in enumerate(distribute(n_instance, n_cpu)) ]

#=============================================================================
    #generate_fcmcnf.generate_instances(0, n_instance, min_n_nodes, max_n_nodes, min_n_arcs, max_n_arcs, min_n_commodities, max_n_commodities, lp_dir, solveInstance)



a = list(map(lambda p: p.start(), processes)) #run processes
b = list(map(lambda p: p.join(), processes)) #join processes
print('Generated')
# Out:
# DiGraph with 15 nodes and 63 edges
# DiGraph with 15 nodes and 55 edges
# DiGraph with 15 nodes and 59 edgesDiGraph with 15 nodes and 64 edges
#
# DiGraph with 15 nodes and 70 edges
# DiGraph with 15 nodes and 60 edges
# DiGraph with 15 nodes and 56 edges
# DiGraph with 15 nodes and 62 edges
# DiGraph with 15 nodes and 70 edges
# 0DiGraph with 15 nodes and 69 edges
#
#
#
# DiGraph with 15 nodes and 63 edgesDiGraph with 15 nodes and 49 edgesDiGraph with 15 nodes and 53 edges
# DiGraph with 15 nodes and 64 edges
# DiGraph with 15 nodes and 55 edges
# 0
# DiGraph with 15 nodes and 52 edges
# DiGraph with 15 nodes and 67 edges
# DiGraph with 15 nodes and 66 edges0
#
# DiGraph with 15 nodes and 70 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 61 edges
# 1
# DiGraph with 15 nodes and 51 edges
# 1
# DiGraph with 15 nodes and 69 edges
# 24
# DiGraph with 15 nodes and 61 edges
# 1
# DiGraph with 15 nodes and 65 edges
# 1
# DiGraph with 15 nodes and 65 edges
# 5
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 15 nodes and 74 edges
# 1
# DiGraph with 15 nodes and 54 edges
# 1
# DiGraph with 15 nodes and 67 edges
# 5
# DiGraph with 15 nodes and 68 edges
# 0
# DiGraph with 15 nodes and 56 edges
# 0
# DiGraph with 15 nodes and 65 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 73 edges
# 1
# DiGraph with 15 nodes and 59 edges
# 1
# DiGraph with 15 nodes and 59 edges
# 1
# DiGraph with 15 nodes and 70 edges
# 51
# DiGraph with 15 nodes and 61 edges
# 28
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 53 edges
# 1
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 15 nodes and 72 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 3
# DiGraph with 15 nodes and 69 edges
# 1
# DiGraph with 15 nodes and 61 edges
# 1
# DiGraph with 15 nodes and 55 edges
# 0
# DiGraph with 15 nodes and 63 edges
# 31
# DiGraph with 15 nodes and 57 edges
# 1
# DiGraph with 15 nodes and 57 edges
# 3
# DiGraph with 15 nodes and 67 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 49 edges
# 1
# DiGraph with 15 nodes and 75 edges
# 1
# DiGraph with 15 nodes and 54 edges
# 1
# DiGraph with 15 nodes and 67 edges
# 1
# DiGraph with 15 nodes and 70 edges
# 17
# DiGraph with 15 nodes and 63 edges
# 91
# DiGraph with 15 nodes and 56 edges
# 5
# DiGraph with 15 nodes and 59 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 52 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 68 edges
# 3
# DiGraph with 15 nodes and 58 edges
# 21
# DiGraph with 15 nodes and 67 edges
# 30
# DiGraph with 15 nodes and 68 edges
# 235
# DiGraph with 15 nodes and 61 edges
# 185
# DiGraph with 15 nodes and 73 edges
# 10
# DiGraph with 15 nodes and 65 edges
# 42
# DiGraph with 15 nodes and 72 edges
# 82
# DiGraph with 15 nodes and 74 edges
# 1
# DiGraph with 15 nodes and 70 edges
# 18
# DiGraph with 15 nodes and 63 edges
# 71
# DiGraph with 15 nodes and 67 edges
# 1
# DiGraph with 15 nodes and 59 edges
# 1
# DiGraph with 15 nodes and 69 edges
# 0
# DiGraph with 15 nodes and 66 edges
# 10
# DiGraph with 15 nodes and 54 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 61 edges
# 1
# DiGraph with 15 nodes and 56 edges
# 1
# DiGraph with 15 nodes and 70 edges
# 1
# DiGraph with 15 nodes and 67 edges
# 1
# DiGraph with 15 nodes and 59 edges
# 47
# DiGraph with 15 nodes and 51 edges
# 1
# DiGraph with 15 nodes and 61 edges
# 55
# DiGraph with 15 nodes and 51 edges
# 0
# DiGraph with 15 nodes and 61 edges
# 119
# DiGraph with 15 nodes and 69 edges
# 199
# DiGraph with 15 nodes and 52 edges
# 1
# DiGraph with 15 nodes and 65 edges
# 1
# DiGraph with 15 nodes and 62 edges
# 15
# DiGraph with 15 nodes and 51 edges
# 1
# DiGraph with 15 nodes and 55 edges
# 11
# DiGraph with 15 nodes and 63 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 73
#
# DiGraph with 15 nodes and 57 edgesDiGraph with 15 nodes and 61 edges
#
# 1
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 15 nodes and 57 edges
# 1
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 15 nodes and 59 edges
# 3
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 68 edges
# 52
# DiGraph with 15 nodes and 63 edges
# 1
# DiGraph with 15 nodes and 58 edges
# 1
# DiGraph with 15 nodes and 70 edges
# 1
# 15DiGraph with 15 nodes and 64 edges
#
# DiGraph with 15 nodes and 60 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 170
# DiGraph with 15 nodes and 63 edges
# 11
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 37
# DiGraph with 15 nodes and 63 edges
# 0
# DiGraph with 15 nodes and 59 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 188
# DiGraph with 15 nodes and 64 edges
# 13
# DiGraph with 15 nodes and 61 edges
# 1
# DiGraph with 15 nodes and 55 edges
# 1
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 15 nodes and 61 edges
# 1
# DiGraph with 15 nodes and 69 edges
# 27
# DiGraph with 15 nodes and 59 edges
# 111
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 0
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 15 nodes and 58 edges
# 0
# DiGraph with 15 nodes and 67 edges
# 1
# DiGraph with 15 nodes and 57 edges
# 15
# DiGraph with 15 nodes and 59 edges
# 41
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 56 edges
# 1
# DiGraph with 15 nodes and 60 edges
# 1
# DiGraph with 15 nodes and 60 edges
# 23
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 31
#
# DiGraph with 15 nodes and 62 edgesDiGraph with 15 nodes and 60 edges
#
# 11
# 1DiGraph with 15 nodes and 56 edges
#
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 53 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 1
# DiGraph with 15 nodes and 56 edges
# 21
# 1
# DiGraph with 15 nodes and 67 edges
# DiGraph with 15 nodes and 71 edges
# 1
# DiGraph with 15 nodes and 51 edges
# 1
# DiGraph with 15 nodes and 73 edges
# 18
# DiGraph with 15 nodes and 63 edges
# 1
# DiGraph with 15 nodes and 67 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 1
# DiGraph with 15 nodes and 68 edges
# 0
# DiGraph with 15 nodes and 76 edges
# 1
# DiGraph with 15 nodes and 58 edges
# 113
# DiGraph with 15 nodes and 56 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 16
# DiGraph with 15 nodes and 64 edges
# 0
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 15 nodes and 67 edges
# 7
# DiGraph with 15 nodes and 59 edges
# 23
# DiGraph with 15 nodes and 61 edges
# 1
# DiGraph with 15 nodes and 69 edges
# 1
# DiGraph with 15 nodes and 65 edges
# 1
# DiGraph with 15 nodes and 53 edges
# 1
# 69DiGraph with 15 nodes and 58 edges
#
# DiGraph with 15 nodes and 61 edges
# 1
# DiGraph with 15 nodes and 60 edges
# 1
# DiGraph with 15 nodes and 51 edges
# 1
# DiGraph with 15 nodes and 53 edges
# 179
# DiGraph with 15 nodes and 56 edges
# 1
# DiGraph with 15 nodes and 51 edges
# 124
# DiGraph with 15 nodes and 55 edges
# 53
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 15 nodes and 61 edges
# 1
# DiGraph with 15 nodes and 58 edges
# 1
# DiGraph with 15 nodes and 82 edges
# 1
# DiGraph with 15 nodes and 54 edges
# 5
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 72 edges
# 9
# DiGraph with 15 nodes and 69 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 57 edges
# 83
# DiGraph with 15 nodes and 53 edges
# 1
# DiGraph with 15 nodes and 77 edges
# 87
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 61 edges
# 3
# DiGraph with 15 nodes and 52 edges
# 1
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 15 nodes and 68 edges
# 819
# DiGraph with 15 nodes and 57 edges
# 1
# DiGraph with 15 nodes and 72 edges
# 5
# DiGraph with 15 nodes and 73 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 25
# DiGraph with 15 nodes and 53 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 77 edges
# 1
# DiGraph with 15 nodes and 54 edges
# 3
# DiGraph with 15 nodes and 52 edges
# 42
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 15 nodes and 56 edges
# 1
# DiGraph with 15 nodes and 55 edges
# 1
# 1
# DiGraph with 15 nodes and 55 edges
# 1
# DiGraph with 15 nodes and 72 edges
# 70
# DiGraph with 15 nodes and 60 edges
# 18
# DiGraph with 15 nodes and 61 edges
# 0
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 15 nodes and 67 edges
# 121
# DiGraph with 15 nodes and 60 edges
# 15
# DiGraph with 15 nodes and 65 edges
# 1
# DiGraph with 15 nodes and 70 edges
# 0
# DiGraph with 15 nodes and 56 edges
# 1
# DiGraph with 15 nodes and 67 edges
# 1
# DiGraph with 15 nodes and 69 edges
# 1
# DiGraph with 15 nodes and 56 edges
# 41
# DiGraph with 15 nodes and 56 edges
# 207
# DiGraph with 15 nodes and 61 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 1
# DiGraph with 15 nodes and 55 edges
# 1
# DiGraph with 15 nodes and 60 edges
# 1
# DiGraph with 15 nodes and 69 edges
# 262
# DiGraph with 15 nodes and 53 edges
# 49
# DiGraph with 15 nodes and 56 edges
# 162
# DiGraph with 15 nodes and 63 edges
# 11
#
# 0
# DiGraph with 15 nodes and 57 edgesDiGraph with 15 nodes and 55 edges
#
# DiGraph with 15 nodes and 46 edges
# 17
# DiGraph with 15 nodes and 63 edges
# 1
# DiGraph with 15 nodes and 62 edges
# 9
# DiGraph with 15 nodes and 67 edges
# 101
# DiGraph with 15 nodes and 70 edges
# 1
# DiGraph with 15 nodes and 61 edges
# 33
# DiGraph with 15 nodes and 66 edges
# 55
# DiGraph with 15 nodes and 59 edges
# 44
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 55 edges
# 1
# DiGraph with 15 nodes and 58 edges
# 75
# DiGraph with 15 nodes and 60 edges
# 1
# DiGraph with 15 nodes and 71 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 58 edges
# 7
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 15 nodes and 65 edges
# 215
# DiGraph with 15 nodes and 71 edges
# 1
# DiGraph with 15 nodes and 82 edges
# 1
# DiGraph with 15 nodes and 59 edges
# 71
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 71 edges
# 1
# DiGraph with 15 nodes and 57 edges
# 12
# DiGraph with 15 nodes and 47 edges
# 0
# DiGraph with 15 nodes and 65 edges
# 1
# DiGraph with 15 nodes and 51 edges
# 418
# DiGraph with 15 nodes and 58 edges
# 23
# DiGraph with 15 nodes and 70 edges
# 7
# DiGraph with 15 nodes and 61 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 0
# DiGraph with 15 nodes and 66 edges
# 2251
#
# DiGraph with 15 nodes and 62 edges
# DiGraph with 15 nodes and 74 edges
# 1
# DiGraph with 15 nodes and 72 edges
# 0
# DiGraph with 15 nodes and 69 edges
# 1
# DiGraph with 15 nodes and 53 edges
# 0
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 78 edges
# 1
# DiGraph with 15 nodes and 60 edges
# 1
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 15 nodes and 57 edges
# 0
# DiGraph with 15 nodes and 61 edges
# 139
# DiGraph with 15 nodes and 70 edges
# 1
# DiGraph with 15 nodes and 62 edges
# 0
# DiGraph with 15 nodes and 61 edges
# 1
# DiGraph with 15 nodes and 76 edges
# 1
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 15 nodes and 56 edges
# 24
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 19
# DiGraph with 15 nodes and 58 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 1
# DiGraph with 15 nodes and 55 edges
# 0
# DiGraph with 15 nodes and 49 edges
# 1
# DiGraph with 15 nodes and 67 edges
# 34
# 17
# DiGraph with 15 nodes and 70 edgesDiGraph with 15 nodes and 45 edges
#
# 1
# DiGraph with 15 nodes and 52 edges
# 178
# DiGraph with 15 nodes and 69 edges
# 1
# 53
# DiGraph with 15 nodes and 62 edges
# DiGraph with 15 nodes and 54 edges
# 149
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 69 edges
# 1
# DiGraph with 15 nodes and 71 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 29
# DiGraph with 15 nodes and 65 edges
# 11
# DiGraph with 15 nodes and 76 edges
# 5
# DiGraph with 15 nodes and 58 edges
# 1
# DiGraph with 15 nodes and 60 edges
# 1
# DiGraph with 15 nodes and 72 edges
# 1
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 63
# DiGraph with 15 nodes and 57 edges
# 3
# DiGraph with 15 nodes and 63 edges
# 1
# DiGraph with 15 nodes and 59 edges
# 1
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 0
# DiGraph with 15 nodes and 65 edges
# 1
# DiGraph with 15 nodes and 60 edges
# 1
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 15 nodes and 59 edges
# 1
# DiGraph with 15 nodes and 59 edges
# 1
# DiGraph with 15 nodes and 60 edges
# 1
# DiGraph with 15 nodes and 59 edges
# 266
# DiGraph with 15 nodes and 53 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 58 edges
# 76
# DiGraph with 15 nodes and 61 edges
# 1
# DiGraph with 15 nodes and 67 edges
# 148
# DiGraph with 15 nodes and 60 edges
# 1
# DiGraph with 15 nodes and 70 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 65
# DiGraph with 15 nodes and 57 edges
# 1
# DiGraph with 15 nodes and 69 edges
# 1
# DiGraph with 15 nodes and 57 edges
# 1
# DiGraph with 15 nodes and 57 edges
# 1
# DiGraph with 15 nodes and 71 edges
# 137
# DiGraph with 15 nodes and 68 edges
# 3
# DiGraph with 15 nodes and 59 edges
# 5
# DiGraph with 15 nodes and 55 edges
# 1
# DiGraph with 15 nodes and 57 edges
# 11
# DiGraph with 15 nodes and 72 edges
# 0
# 1
# DiGraph with 15 nodes and 72 edges
# DiGraph with 15 nodes and 65 edges
# 1
# DiGraph with 15 nodes and 60 edges
# 1
# DiGraph with 15 nodes and 57 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 17
#
# DiGraph with 15 nodes and 62 edgesDiGraph with 15 nodes and 67 edges
#
# 12
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 15 nodes and 67 edges
# 1
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 15 nodes and 68 edges
# 45
# DiGraph with 15 nodes and 88 edges
# 1
# DiGraph with 15 nodes and 69 edges
# 1
# DiGraph with 15 nodes and 59 edges
# 0
# DiGraph with 15 nodes and 63 edges
# 12
# DiGraph with 15 nodes and 49 edges
# 0
# DiGraph with 15 nodes and 52 edges
# 1
# DiGraph with 15 nodes and 57 edges
# 0
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 61 edges
# 1
# DiGraph with 15 nodes and 73 edges
# 1
# DiGraph with 15 nodes and 49 edges
# 0
# DiGraph with 15 nodes and 63 edges
# 1
# DiGraph with 15 nodes and 46 edges
# 0
# DiGraph with 15 nodes and 57 edges
# 1
# DiGraph with 15 nodes and 47 edges
# 1
# DiGraph with 15 nodes and 60 edges
# 1
# DiGraph with 15 nodes and 58 edges
# 0
# DiGraph with 15 nodes and 58 edges
# 139
# DiGraph with 15 nodes and 56 edges1
#
# DiGraph with 15 nodes and 67 edges
# 320
# DiGraph with 15 nodes and 67 edges
# 1
# DiGraph with 15 nodes and 53 edges
# 66
# DiGraph with 15 nodes and 64 edges
# 5
# DiGraph with 15 nodes and 56 edges
# 1
# DiGraph with 15 nodes and 51 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 57 edges
# 1
# DiGraph with 15 nodes and 50 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 9
# DiGraph with 15 nodes and 67 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 53
# DiGraph with 15 nodes and 56 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 53 edges
# 1
# DiGraph with 15 nodes and 59 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 54 edges
# 0
# DiGraph with 15 nodes and 60 edges
# 1
# DiGraph with 15 nodes and 48 edges
# 9
# DiGraph with 15 nodes and 63 edges
# 11
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 15 nodes and 61 edges
# 228
# DiGraph with 15 nodes and 73 edges
# 225
# DiGraph with 15 nodes and 65 edges
# 1
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 15 nodes and 68 edges
# 12
# DiGraph with 15 nodes and 67 edges
# 1
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 15 nodes and 54 edges
# 31
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 0
# DiGraph with 15 nodes and 70 edges
# 1
# DiGraph with 15 nodes and 62 edges
# 156
# DiGraph with 15 nodes and 70 edges
# 27
# DiGraph with 15 nodes and 65 edges
# 0
# DiGraph with 15 nodes and 56 edges
# 155
# DiGraph with 15 nodes and 63 edges
# 46
# DiGraph with 15 nodes and 59 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 74 edges
# 61
# DiGraph with 15 nodes and 69 edges
# 1
# DiGraph with 15 nodes and 55 edges
# 0
# DiGraph with 15 nodes and 59 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 13
# DiGraph with 15 nodes and 64 edges
# 217
# DiGraph with 15 nodes and 62 edges
# 3
# DiGraph with 15 nodes and 63 edges
# 78
# DiGraph with 15 nodes and 57 edges
# 1
# DiGraph with 15 nodes and 74 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 11
# DiGraph with 15 nodes and 55 edges
# 0
# DiGraph with 15 nodes and 52 edges
# 1
# DiGraph with 15 nodes and 73 edges
# 1
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 15 nodes and 52 edges
# 0
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 15 nodes and 78 edges
# 1
# DiGraph with 15 nodes and 65 edges
# 3
# DiGraph with 15 nodes and 60 edges
# 1
# DiGraph with 15 nodes and 58 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 1
# DiGraph with 15 nodes and 71 edges
# 9
# DiGraph with 15 nodes and 60 edges
# 1
# DiGraph with 15 nodes and 59 edges
# 0
# DiGraph with 15 nodes and 65 edges
# 1
# DiGraph with 15 nodes and 58 edges
# 29
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 15 nodes and 68 edges
# 3
# DiGraph with 15 nodes and 65 edges
# 1
# DiGraph with 15 nodes and 61 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 78 edges
# 1
# DiGraph with 15 nodes and 56 edges
# 1
# DiGraph with 15 nodes and 61 edges
# 1
# DiGraph with 15 nodes and 54 edges
# 0
# DiGraph with 15 nodes and 73 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 1
# DiGraph with 15 nodes and 77 edges
# 55
# DiGraph with 15 nodes and 60 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 69 edges
# 29
# DiGraph with 15 nodes and 68 edges
# 79
# DiGraph with 15 nodes and 63 edges
# 40
# DiGraph with 15 nodes and 57 edges
# 1
# DiGraph with 15 nodes and 69 edges
# 1
# DiGraph with 15 nodes and 54 edges
# 271
# DiGraph with 15 nodes and 61 edges
# 8
# DiGraph with 15 nodes and 60 edges
# 9
# DiGraph with 15 nodes and 63 edges
# 12
# DiGraph with 15 nodes and 51 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 9
# DiGraph with 15 nodes and 77 edges
# 1
# DiGraph with 15 nodes and 67 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 57 edges
# 67
# DiGraph with 15 nodes and 58 edges
# 0
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 15 nodes and 57 edges
# 0
# DiGraph with 15 nodes and 60 edges
# 187
# DiGraph with 15 nodes and 65 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 0
# DiGraph with 15 nodes and 49 edges
# 0
# DiGraph with 15 nodes and 54 edges
# 0
# 1
# DiGraph with 15 nodes and 53 edges
# DiGraph with 15 nodes and 68 edges
# 3
# DiGraph with 15 nodes and 57 edges
# 1
# DiGraph with 15 nodes and 68 edges
# 191
# DiGraph with 15 nodes and 47 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 60 edges
# 104
# DiGraph with 15 nodes and 66 edges
# 24
# DiGraph with 15 nodes and 58 edges
# 169
# DiGraph with 15 nodes and 78 edges
# 1
# DiGraph with 15 nodes and 49 edges
# 106
# DiGraph with 15 nodes and 50 edges
# 11098
#
# DiGraph with 15 nodes and 63 edges
# DiGraph with 15 nodes and 46 edges
# 1
# DiGraph with 15 nodes and 57 edges
# 1
# DiGraph with 15 nodes and 72 edges
# 308
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 69 edges
# 76
# DiGraph with 15 nodes and 54 edges
# 40
# DiGraph with 15 nodes and 56 edges
# 15
# DiGraph with 15 nodes and 65 edges
# 11
#
# DiGraph with 15 nodes and 58 edgesDiGraph with 15 nodes and 72 edges
#
# 1
# DiGraph with 15 nodes and 70 edges
# 1
# 295
# DiGraph with 15 nodes and 68 edges
# DiGraph with 15 nodes and 65 edges
# 1
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 15 nodes and 65 edges
# 302
# DiGraph with 15 nodes and 51 edges
# 196
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 15 nodes and 74 edges
# 1
# DiGraph with 15 nodes and 51 edges
# 51
# DiGraph with 15 nodes and 49 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 65 edges
# 1
# DiGraph with 15 nodes and 65 edges
# 1
# DiGraph with 15 nodes and 71 edges
# 118
# DiGraph with 15 nodes and 61 edges
# 347
# DiGraph with 15 nodes and 55 edges
# 38
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 65 edges
# 40
# 1DiGraph with 15 nodes and 58 edges
#
# DiGraph with 15 nodes and 60 edges
# 60
# DiGraph with 15 nodes and 59 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 1
# DiGraph with 15 nodes and 72 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 21
# DiGraph with 15 nodes and 74 edges
# 5
# DiGraph with 15 nodes and 53 edges
# 1
# DiGraph with 15 nodes and 74 edges
# 5
# DiGraph with 15 nodes and 48 edges
# 0
# DiGraph with 15 nodes and 75 edges
# 13
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 68 edges
# 5
# DiGraph with 15 nodes and 61 edges1
#
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 15 nodes and 71 edges
# 1
# DiGraph with 15 nodes and 61 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 1
# DiGraph with 15 nodes and 61 edges
# 0
# DiGraph with 15 nodes and 60 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 0
# DiGraph with 15 nodes and 69 edges
# 1
# DiGraph with 15 nodes and 65 edges
# 1
# DiGraph with 15 nodes and 58 edges
# 284
# DiGraph with 15 nodes and 49 edges
# 100
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 69 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 1
# DiGraph with 15 nodes and 53 edges
# 0
# DiGraph with 15 nodes and 64 edges
# 75
# 1DiGraph with 15 nodes and 66 edges
#
# DiGraph with 15 nodes and 57 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 9
# DiGraph with 15 nodes and 73 edges
# 8
# DiGraph with 15 nodes and 67 edges
# 1
# DiGraph with 15 nodes and 60 edges
# 27
# DiGraph with 15 nodes and 54 edges
# 0
# DiGraph with 15 nodes and 71 edges
# 1
# DiGraph with 15 nodes and 52 edges
# 351
# DiGraph with 15 nodes and 54 edges
# 58
# DiGraph with 15 nodes and 61 edges
# 85
# DiGraph with 15 nodes and 61 edges
# 0
# DiGraph with 15 nodes and 65 edges
# 26
# DiGraph with 15 nodes and 57 edges
# 181
# DiGraph with 15 nodes and 63 edges
# 1
# DiGraph with 15 nodes and 62 edges
# 69
# DiGraph with 15 nodes and 65 edges
# 99
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 5
# DiGraph with 15 nodes and 61 edges
# 19
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 15 nodes and 56 edges
# 3
# DiGraph with 15 nodes and 68 edges
# 97
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 57 edges
# 1
# DiGraph with 15 nodes and 69 edges
# 1
# DiGraph with 15 nodes and 59 edges
# 1
# DiGraph with 15 nodes and 58 edges
# 1
# DiGraph with 15 nodes and 65 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 3
# DiGraph with 15 nodes and 60 edges
# 1
# DiGraph with 15 nodes and 67 edges
# 64
# DiGraph with 15 nodes and 52 edges
# 1
# DiGraph with 15 nodes and 57 edges
# 0
# DiGraph with 15 nodes and 54 edges
# 65
# DiGraph with 15 nodes and 51 edges
# 184
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 15 nodes and 67 edges
# 1
# DiGraph with 15 nodes and 59 edges
# 1
# DiGraph with 15 nodes and 58 edges
# 1
# DiGraph with 15 nodes and 75 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 63
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 92
# DiGraph with 15 nodes and 61 edges
# 1
# DiGraph with 15 nodes and 56 edges
# 1
# DiGraph with 15 nodes and 76 edges
# 1
# DiGraph with 15 nodes and 59 edges
# 280
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 59 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 60 edges
# 28
# DiGraph with 15 nodes and 77 edges
# 145
# DiGraph with 15 nodes and 71 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 41
# DiGraph with 15 nodes and 80 edges
# 3
# DiGraph with 15 nodes and 63 edges
# 45
# DiGraph with 15 nodes and 66 edges
# 11
# DiGraph with 15 nodes and 58 edges
# 9
# DiGraph with 15 nodes and 72 edges
# 1
# DiGraph with 15 nodes and 58 edges
# 1
# DiGraph with 15 nodes and 65 edges
# 119
# DiGraph with 15 nodes and 56 edges
# 15
# DiGraph with 15 nodes and 63 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 5
# DiGraph with 15 nodes and 65 edges
# 11
# DiGraph with 15 nodes and 49 edges
# 1
# DiGraph with 15 nodes and 67 edges
# 9
# DiGraph with 15 nodes and 67 edges
# 1
# DiGraph with 15 nodes and 52 edges
# 0
# DiGraph with 15 nodes and 54 edges
# 1
# DiGraph with 15 nodes and 50 edges
# 1
# DiGraph with 15 nodes and 59 edges
# 1
# DiGraph with 15 nodes and 54 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 67 edges
# 1
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 65 edges
# 13
# DiGraph with 15 nodes and 57 edges
# 1
# DiGraph with 15 nodes and 53 edges
# 1
# DiGraph with 15 nodes and 53 edges
# 1
# DiGraph with 15 nodes and 59 edges
# 1
# DiGraph with 15 nodes and 69 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 75 edges
# 255
# DiGraph with 15 nodes and 71 edges
# 0
# DiGraph with 15 nodes and 70 edges
# 1
# DiGraph with 15 nodes and 52 edges
# 0
# DiGraph with 15 nodes and 63 edges
# 19
# DiGraph with 15 nodes and 66 edges
# 256
# DiGraph with 15 nodes and 57 edges
# 45
# DiGraph with 15 nodes and 69 edges
# 1
# DiGraph with 15 nodes and 67 edges
# 20
# DiGraph with 15 nodes and 67 edges
# 7
# DiGraph with 15 nodes and 50 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 0
# DiGraph with 15 nodes and 75 edges
# 1
# DiGraph with 15 nodes and 61 edges
# 3
# DiGraph with 15 nodes and 71 edges
# 1
# DiGraph with 15 nodes and 59 edges
# 1
# DiGraph with 15 nodes and 71 edges
# 7
# DiGraph with 15 nodes and 61 edges
# 3
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 15 nodes and 65 edges
# 1
# DiGraph with 15 nodes and 59 edges
# 1
# DiGraph with 15 nodes and 53 edges
# 54
# DiGraph with 15 nodes and 58 edges
# 68
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 70 edges
# 1
# DiGraph with 15 nodes and 60 edges
# 0
# DiGraph with 15 nodes and 61 edges
# 32
# DiGraph with 15 nodes and 70 edges
# 59
# DiGraph with 15 nodes and 66 edges
# 279
# DiGraph with 15 nodes and 53 edges
# 13
# DiGraph with 15 nodes and 73 edges
# 1
# DiGraph with 15 nodes and 59 edges
# 98
# DiGraph with 15 nodes and 76 edges
# 134
# DiGraph with 15 nodes and 82 edges
# 1
# DiGraph with 15 nodes and 65 edges
# 48
# DiGraph with 15 nodes and 63 edges
# 1
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 15 nodes and 60 edges
# 3
# DiGraph with 15 nodes and 75 edges
# 1
# DiGraph with 15 nodes and 56 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 3
# DiGraph with 15 nodes and 75 edges
# 1
# 1
# DiGraph with 15 nodes and 63 edgesDiGraph with 15 nodes and 67 edges
#
# 1
# DiGraph with 15 nodes and 67 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 1
# DiGraph with 15 nodes and 68 edges
# 14
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 77
# DiGraph with 15 nodes and 69 edges
# 8
# DiGraph with 15 nodes and 55 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 1
# DiGraph with 15 nodes and 61 edges
# 1
# DiGraph with 15 nodes and 73 edges
# 1
# DiGraph with 15 nodes and 65 edges
# 1
# DiGraph with 15 nodes and 68 edges
# 7
# DiGraph with 15 nodes and 72 edges
# 305
# DiGraph with 15 nodes and 55 edges
# 1
# DiGraph with 15 nodes and 56 edges
# 0
# DiGraph with 15 nodes and 56 edges
# 5
# 1
# DiGraph with 15 nodes and 63 edges
# DiGraph with 15 nodes and 72 edges
# 1
# DiGraph with 15 nodes and 60 edges
# 1
# DiGraph with 15 nodes and 61 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 7
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 15 nodes and 70 edges
# 1
# DiGraph with 15 nodes and 51 edges
# 160
#
# DiGraph with 15 nodes and 63 edges
# DiGraph with 15 nodes and 56 edges
# 1
# DiGraph with 15 nodes and 57 edges
# 152
# DiGraph with 15 nodes and 71 edges
# 1
# DiGraph with 15 nodes and 58 edges
# 1
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 15 nodes and 54 edges
# 1
# DiGraph with 15 nodes and 69 edges
# 1
# DiGraph with 15 nodes and 46 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 1
# DiGraph with 15 nodes and 58 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 0
# DiGraph with 15 nodes and 75 edges
# 1
# DiGraph with 15 nodes and 56 edges
# 41
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 115
# DiGraph with 15 nodes and 65 edges
# 0
# DiGraph with 15 nodes and 50 edges
# 52
# DiGraph with 15 nodes and 67 edges
# 1
# DiGraph with 15 nodes and 57 edges
# 3
# DiGraph with 15 nodes and 68 edges
# 40
# DiGraph with 15 nodes and 65 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 7
# DiGraph with 15 nodes and 60 edges
# 1
# DiGraph with 15 nodes and 69 edges
# 1
# DiGraph with 15 nodes and 69 edges
# 7
# DiGraph with 15 nodes and 72 edges
# 64
# DiGraph with 15 nodes and 55 edges
# 0
# DiGraph with 15 nodes and 60 edges
# 53
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 73 edges
# 1
# DiGraph with 15 nodes and 55 edges
# 1
# DiGraph with 15 nodes and 53 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 72 edges
# 35
# DiGraph with 15 nodes and 65 edges
# 104
# DiGraph with 15 nodes and 63 edges
# 1
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 15 nodes and 60 edges
# 0
# DiGraph with 15 nodes and 55 edges
# 96
# DiGraph with 15 nodes and 63 edges
# 1
# DiGraph with 15 nodes and 55 edges
# 9
# DiGraph with 15 nodes and 74 edges
# 1
# DiGraph with 15 nodes and 67 edges
# 1
# DiGraph with 15 nodes and 68 edges
# 31
#
# DiGraph with 15 nodes and 73 edgesDiGraph with 15 nodes and 64 edges
#
# 172
# DiGraph with 15 nodes and 69 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 65 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 207
# DiGraph with 15 nodes and 67 edges
# 1
# DiGraph with 15 nodes and 58 edges
# 0
# DiGraph with 15 nodes and 65 edges
# 0
# DiGraph with 15 nodes and 67 edges
# 1
# DiGraph with 15 nodes and 59 edges
# 3
# DiGraph with 15 nodes and 58 edges
# 1
# 1DiGraph with 15 nodes and 64 edges
#
# DiGraph with 15 nodes and 73 edges
# 72
# DiGraph with 15 nodes and 70 edges
# 292
# DiGraph with 15 nodes and 69 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 14
# DiGraph with 15 nodes and 56 edges
# 1
# DiGraph with 15 nodes and 78 edges
# 69
# DiGraph with 15 nodes and 54 edges59
#
# DiGraph with 15 nodes and 73 edges
# 11
# DiGraph with 15 nodes and 67 edges
# 1
# DiGraph with 15 nodes and 70 edges
# 1
# DiGraph with 15 nodes and 59 edges
# 1
# DiGraph with 15 nodes and 59 edges
# 1
# DiGraph with 15 nodes and 60 edges
# 619
# DiGraph with 15 nodes and 57 edges
# 288
# DiGraph with 15 nodes and 61 edges
# 1
# DiGraph with 15 nodes and 65 edges
# 57
# DiGraph with 15 nodes and 69 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 61 edges
# 1
# DiGraph with 15 nodes and 57 edges
# 1
# DiGraph with 15 nodes and 53 edges
# 1
# DiGraph with 15 nodes and 69 edges
# 1
# DiGraph with 15 nodes and 73 edges
# 7
# DiGraph with 15 nodes and 55 edges
# 1
# DiGraph with 15 nodes and 69 edges
# 1
# DiGraph with 15 nodes and 61 edges
# 1
# DiGraph with 15 nodes and 69 edges
# 309
# DiGraph with 15 nodes and 54 edges
# 61
# DiGraph with 15 nodes and 54 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 154
# DiGraph with 15 nodes and 53 edges
# 1
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 15 nodes and 54 edges
# 1
# DiGraph with 15 nodes and 52 edges
# 1
# DiGraph with 15 nodes and 65 edges
# 92
# DiGraph with 15 nodes and 66 edges
# 63
# DiGraph with 15 nodes and 65 edges
# 1
# DiGraph with 15 nodes and 69 edges
# 160
# DiGraph with 15 nodes and 66 edges
# 8
# DiGraph with 15 nodes and 61 edges
# 1
# DiGraph with 15 nodes and 56 edges
# 1
# DiGraph with 15 nodes and 51 edges
# 0
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 15 nodes and 67 edges
# 1
# DiGraph with 15 nodes and 74 edges
# 13
# DiGraph with 15 nodes and 70 edges
# 1
# DiGraph with 15 nodes and 60 edges
# 1
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 15 nodes and 49 edges
# 43
# DiGraph with 15 nodes and 58 edges
# 1
# DiGraph with 15 nodes and 65 edges
# 0
# DiGraph with 15 nodes and 57 edges
# 1
# DiGraph with 15 nodes and 57 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 1
# DiGraph with 15 nodes and 67 edges
# 9
# DiGraph with 15 nodes and 58 edges
# 211
# DiGraph with 15 nodes and 58 edges
# 1
# DiGraph with 15 nodes and 47 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 0
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 15 nodes and 61 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 1
# DiGraph with 15 nodes and 55 edges
# 1
# DiGraph with 15 nodes and 60 edges
# 1
# DiGraph with 15 nodes and 65 edges
# 1
# DiGraph with 15 nodes and 74 edges
# 1
# DiGraph with 15 nodes and 62 edges
# 107
# DiGraph with 15 nodes and 58 edges
# 1
# DiGraph with 15 nodes and 61 edges
# 0
# DiGraph with 15 nodes and 46 edges
# 0
# DiGraph with 15 nodes and 61 edges
# 29
# DiGraph with 15 nodes and 71 edges
# 1
# DiGraph with 15 nodes and 55 edges
# 1
# DiGraph with 15 nodes and 62 edges
# 1
# 84
# DiGraph with 15 nodes and 48 edges
# 321
# DiGraph with 15 nodes and 60 edges
# 1
# DiGraph with 15 nodes and 60 edges
# 49
# DiGraph with 15 nodes and 52 edges
# 1
# DiGraph with 15 nodes and 70 edges
# 1
# DiGraph with 15 nodes and 56 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 77 edges
# 1
# DiGraph with 15 nodes and 67 edges
# 1
# 54
# DiGraph with 15 nodes and 68 edges
# 7
# DiGraph with 15 nodes and 66 edges
# 52
# DiGraph with 15 nodes and 63 edges
# 1
# DiGraph with 15 nodes and 60 edges
# 9
# DiGraph with 15 nodes and 64 edges
# 88
# DiGraph with 15 nodes and 65 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 72 edges
# 217
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 15 nodes and 76 edges
# 1
# DiGraph with 15 nodes and 45 edges
# 1
# DiGraph with 15 nodes and 54 edges
# 88
# DiGraph with 15 nodes and 59 edges
# 0
# DiGraph with 15 nodes and 76 edges
# 1
# DiGraph with 15 nodes and 65 edges
# 5
# DiGraph with 15 nodes and 65 edges
# 32
# DiGraph with 15 nodes and 56 edges
# 1
# DiGraph with 15 nodes and 55 edges
# 1
# DiGraph with 15 nodes and 62 edges
# 69
# DiGraph with 15 nodes and 54 edges
# 9
# DiGraph with 15 nodes and 63 edges
# 3
# DiGraph with 15 nodes and 72 edges
# 1
# 1
# DiGraph with 15 nodes and 65 edges
# 1
# DiGraph with 15 nodes and 55 edges
# 0
# DiGraph with 15 nodes and 68 edges
# 6
# DiGraph with 15 nodes and 75 edges
# 4
# DiGraph with 15 nodes and 63 edges
# 1
# DiGraph with 15 nodes and 57 edges
# 0
# DiGraph with 15 nodes and 56 edges
# 17
# DiGraph with 15 nodes and 59 edges
# 177
# 59
# DiGraph with 15 nodes and 53 edges
# 7
# DiGraph with 15 nodes and 56 edges
# 1
# DiGraph with 15 nodes and 53 edges
# 7
# DiGraph with 15 nodes and 72 edges
# 1
# DiGraph with 15 nodes and 47 edges
# 178
# DiGraph with 15 nodes and 57 edges
# 580
# DiGraph with 15 nodes and 60 edges
# 1
# DiGraph with 15 nodes and 70 edges
# 1
# DiGraph with 15 nodes and 58 edges
# 1
# DiGraph with 15 nodes and 68 edges
# 11
# DiGraph with 15 nodes and 68 edges
# 1
# 5
# DiGraph with 15 nodes and 61 edges
# 1
# DiGraph with 15 nodes and 59 edges
# 1
# DiGraph with 15 nodes and 56 edges
# 11
# DiGraph with 15 nodes and 74 edges
# 1
# DiGraph with 15 nodes and 56 edges
# 1
# DiGraph with 15 nodes and 51 edges
# 1
# DiGraph with 15 nodes and 70 edges
# 329
# DiGraph with 15 nodes and 60 edges
# 0
# DiGraph with 15 nodes and 61 edges
# 1
# DiGraph with 15 nodes and 56 edges
# 1
# DiGraph with 15 nodes and 55 edges
# 267
# DiGraph with 15 nodes and 70 edges
# 1
# 1
# DiGraph with 15 nodes and 59 edges
# 0
# DiGraph with 15 nodes and 67 edges
# 0
# DiGraph with 15 nodes and 65 edges
# 3
# DiGraph with 15 nodes and 58 edges
# 90
# DiGraph with 15 nodes and 67 edges
# 1
# 6
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 15 nodes and 47 edges
# 0
# DiGraph with 15 nodes and 55 edges
# 9
# 1
# DiGraph with 15 nodes and 69 edges
# 154
# DiGraph with 15 nodes and 53 edges
# 7
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 58 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 9
# DiGraph with 15 nodes and 58 edges
# 3
# DiGraph with 15 nodes and 58 edges
# 443
# DiGraph with 15 nodes and 57 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 1
# DiGraph with 15 nodes and 57 edges
# 121
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 15 nodes and 60 edges
# 1
# DiGraph with 15 nodes and 69 edges
# 3
# DiGraph with 15 nodes and 67 edges
# 93
# DiGraph with 15 nodes and 72 edges
# 1
# DiGraph with 15 nodes and 73 edges
# 1
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 15 nodes and 71 edges
# 1
# DiGraph with 15 nodes and 57 edges
# 13
# DiGraph with 15 nodes and 63 edges
# 1
# DiGraph with 15 nodes and 77 edges
# 1
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 15 nodes and 65 edges
# 1
# DiGraph with 15 nodes and 59 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 51 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 220
# DiGraph with 15 nodes and 60 edges
# 0
# DiGraph with 15 nodes and 60 edges
# 0
# DiGraph with 15 nodes and 67 edges
# 1
# DiGraph with 15 nodes and 61 edges
# 1
# DiGraph with 15 nodes and 56 edges
# 1
# DiGraph with 15 nodes and 58 edges
# 1
# DiGraph with 15 nodes and 56 edges
# 3
# DiGraph with 15 nodes and 63 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 0
# DiGraph with 15 nodes and 58 edges
# 1
# DiGraph with 15 nodes and 62 edges
# 334
# DiGraph with 15 nodes and 57 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 130
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 15 nodes and 60 edges
# 7
# DiGraph with 15 nodes and 74 edges
# 1
# DiGraph with 15 nodes and 59 edges
# 87
# DiGraph with 15 nodes and 61 edges
# 1
# DiGraph with 15 nodes and 60 edges
# 1
# DiGraph with 15 nodes and 67 edges
# 1
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 15 nodes and 57 edges
# 48
# DiGraph with 15 nodes and 58 edges
# 92
# DiGraph with 15 nodes and 58 edges
# 1
# 1
# DiGraph with 15 nodes and 65 edges
# 1
# DiGraph with 15 nodes and 59 edges
# 0
# DiGraph with 15 nodes and 71 edges
# 92
# DiGraph with 15 nodes and 75 edges
# 1
# DiGraph with 15 nodes and 61 edges
# 0
# 7
# DiGraph with 15 nodes and 65 edges
# 39
# DiGraph with 15 nodes and 60 edges
# 0
# 1
# 31
# DiGraph with 15 nodes and 56 edges
# 1
# DiGraph with 15 nodes and 67 edges
# 0
# DiGraph with 15 nodes and 77 edges
# 172
# DiGraph with 15 nodes and 50 edges
# 1
# 1
# DiGraph with 15 nodes and 63 edges
# 1
# DiGraph with 15 nodes and 57 edges
# 1
# DiGraph with 15 nodes and 59 edges
# 0
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 15 nodes and 60 edges
# 1
# DiGraph with 15 nodes and 67 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 1
# 0
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 55
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 15 nodes and 60 edges
# 1
# DiGraph with 15 nodes and 56 edges
# 1
# DiGraph with 15 nodes and 70 edges
# 1
# DiGraph with 15 nodes and 74 edges
# 0
# DiGraph with 15 nodes and 65 edges
# 5
# DiGraph with 15 nodes and 55 edges
# 1
# DiGraph with 15 nodes and 51 edges
# 45
# DiGraph with 15 nodes and 68 edges
# 3
# DiGraph with 15 nodes and 71 edges
# 1
# Generated
